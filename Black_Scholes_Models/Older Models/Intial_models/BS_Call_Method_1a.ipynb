# %%
# investigate normalization after. Also how to print graphs with epochs and data. 
# Read the black scholes paper -> find ideas to relate to yours.

# %%
pip install pytorch-lightning
# Out:
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.4.1-py3-none-any.whl (915 kB)
#      |████████████████████████████████| 915 kB 3.8 MB/s
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.19.5)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.41.1)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 12.4 MB/s
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Collecting PyYAML>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 19.2 MB/s
# Collecting tensorboard!=2.5.0,>=2.2.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 21.6 MB/s
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (3.7.4.3)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 57.7 MB/s
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (21.0)
# Collecting torchmetrics>=0.4.0
#   Downloading torchmetrics-0.4.1-py3-none-any.whl (234 kB)
#      |████████████████████████████████| 234 kB 48.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 48.0 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning) (2.4.7)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (3.3.4)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (1.34.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (1.8.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (3.17.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (0.12.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (57.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (1.32.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (0.4.4)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (0.36.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (4.6.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (3.1.1)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 49.0 MB/s
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (21.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 49.8 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning) (3.5.0)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=f22e1dc325d2e5e151105b30d0ed045377962399e6d06bd761c78129f3605fc0
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# Installing collected packages: multidict, yarl, async-timeout, fsspec, aiohttp, torchmetrics, tensorboard, PyYAML, pyDeprecate, future, pytorch-lightning
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed PyYAML-5.4.1 aiohttp-3.7.4.post0 async-timeout-3.0.1 fsspec-2021.7.0 future-0.18.2 multidict-5.1.0 pyDeprecate-0.3.1 pytorch-lightning-1.4.1 tensorboard-2.6.0 torchmetrics-0.4.1 yarl-1.6.3

# %%
import numpy as np
import scipy.stats as si
import sympy as sy
from sympy.stats import Normal, cdf
from sympy import init_printing
init_printing()
import torch 
from torch import autograd
from torch import nn # import neural network 
from torch import optim 
from torchvision import datasets, transforms
from torch.utils.data import random_split, DataLoader
import pytorch_lightning as pl

# %%
# stock price - between [50,150]

a,b = 500 ,1 #dimension of the pytorch tensor to be generated
low , high = 50 , 150 #range of uniform distribution
torch.manual_seed(50) #Fx the values
S_t = torch.distributions.uniform.Uniform(low, high).sample([a,b]) # samples from low and high values. a,b are the dimensions

Stock = S_t.view(500,1)
print(Stock)
# Out:
# tensor([[111.8022],
#         [ 56.8693],
#         [ 88.9275],
#         [ 54.0412],
#         [ 90.1323],
#         [ 64.4163],
#         [ 96.0457],
#         [ 98.7675],
#         [109.2665],
#         [146.3383],
#         [ 62.3002],
#         [ 90.4769],
#         [ 99.8482],
#         [149.8734],
#         [110.4864],
#         [102.2903],
#         [119.7392],
#         [ 75.0510],
#         [ 86.2393],
#         [ 96.2094],
#         [121.4548],
#         [100.5850],
#         [ 55.1794],
#         [ 74.9155],
#         [ 73.9515],
#         [ 92.3287],
#         [ 50.2160],
#         [118.4802],
#         [124.9681],
#         [ 74.8874],
#         [ 84.9019],
#         [ 69.5258],
#         [ 77.9231],
#         [ 75.2583],
#         [ 87.9211],
#         [126.8585],
#         [119.0705],
#         [125.2633],
#         [ 61.8385],
#         [136.9878],
#         [133.9136],
#         [ 55.3168],
#         [ 67.0496],
#         [ 79.1351],
#         [106.8239],
#         [ 53.7998],
#         [ 77.1507],
#         [119.8719],
#         [ 59.4418],
#         [117.1934],
#         [ 87.8224],
#         [137.3787],
#         [122.6670],
#         [144.8607],
#         [ 93.8819],
#         [ 95.8858],
#         [ 53.5889],
#         [ 85.2484],
#         [ 53.8893],
#         [ 88.8037],
#         [ 63.1897],
#         [100.1778],
#         [130.7733],
#         [143.2230],
#         [106.8028],
#         [100.3421],
#         [ 70.7407],
#         [ 97.7853],
#         [ 92.0294],
#         [ 90.1439],
#         [ 54.3583],
#         [114.9041],
#         [140.0677],
#         [132.7425],
#         [ 87.8462],
#         [125.1778],
#         [ 78.3886],
#         [122.1972],
#         [134.2083],
#         [ 74.7435],
#         [118.3435],
#         [ 55.5103],
#         [128.2412],
#         [129.0052],
#         [145.9618],
#         [110.6487],
#         [109.2576],
#         [122.9967],
#         [147.6825],
#         [146.8043],
#         [ 64.9420],
#         [148.2564],
#         [129.2070],
#         [108.4153],
#         [146.2802],
#         [ 81.9244],
#         [107.4963],
#         [ 65.3814],
#         [ 75.4013],
#         [147.0265],
#         [100.1963],
#         [ 80.1839],
#         [138.3242],
#         [ 69.2095],
#         [126.8634],
#         [ 75.2355],
#         [ 86.6760],
#         [ 54.8360],
#         [128.2946],
#         [120.3202],
#         [122.6515],
#         [107.9401],
#         [ 64.1226],
#         [131.0472],
#         [142.8371],
#         [144.4445],
#         [115.3758],
#         [103.4441],
#         [130.2519],
#         [104.8402],
#         [107.3779],
#         [ 92.2535],
#         [125.0640],
#         [116.4118],
#         [ 81.2952],
#         [143.9452],
#         [ 81.5835],
#         [144.8639],
#         [ 76.6189],
#         [ 65.3774],
#         [ 95.0832],
#         [126.0155],
#         [132.6007],
#         [ 99.7973],
#         [ 59.9247],
#         [ 77.0531],
#         [ 82.9797],
#         [ 59.2933],
#         [101.4269],
#         [100.8180],
#         [125.3950],
#         [117.1841],
#         [135.4686],
#         [116.6184],
#         [ 60.2182],
#         [ 84.0601],
#         [ 80.0403],
#         [116.0126],
#         [ 72.6588],
#         [134.4357],
#         [130.8307],
#         [130.5478],
#         [105.2958],
#         [ 56.2752],
#         [141.5727],
#         [ 91.6102],
#         [ 89.2605],
#         [131.4030],
#         [142.5525],
#         [ 54.3447],
#         [105.9774],
#         [128.6119],
#         [126.0941],
#         [ 50.6839],
#         [ 54.6233],
#         [120.8175],
#         [ 89.3651],
#         [ 72.9761],
#         [ 80.0226],
#         [106.2552],
#         [ 84.4200],
#         [119.3513],
#         [129.7872],
#         [ 52.1539],
#         [ 62.8108],
#         [ 78.9419],
#         [129.1450],
#         [ 78.5752],
#         [114.6720],
#         [133.5209],
#         [ 76.5139],
#         [ 92.4880],
#         [148.8817],
#         [ 56.8241],
#         [ 81.4024],
#         [ 51.5579],
#         [ 70.9069],
#         [ 77.0626],
#         [147.3270],
#         [ 80.6339],
#         [136.7362],
#         [ 98.3800],
#         [110.2844],
#         [109.8072],
#         [147.2259],
#         [144.8073],
#         [136.9628],
#         [133.0942],
#         [ 79.6517],
#         [118.9982],
#         [122.2607],
#         [125.2726],
#         [ 94.9158],
#         [ 78.8612],
#         [100.4069],
#         [146.0580],
#         [118.3132],
#         [108.1192],
#         [ 55.2039],
#         [128.0969],
#         [ 51.9804],
#         [ 90.9344],
#         [117.7581],
#         [ 51.7293],
#         [102.6645],
#         [134.8196],
#         [ 86.8288],
#         [ 87.9405],
#         [ 55.0572],
#         [ 87.7636],
#         [148.0243],
#         [ 85.6191],
#         [129.9864],
#         [108.6369],
#         [ 99.8216],
#         [116.5699],
#         [101.7567],
#         [ 90.9188],
#         [112.1715],
#         [101.1611],
#         [148.7027],
#         [132.1578],
#         [ 57.6714],
#         [ 81.1708],
#         [ 50.4924],
#         [123.6733],
#         [141.6728],
#         [ 72.2994],
#         [104.9301],
#         [ 75.7377],
#         [110.8595],
#         [100.4226],
#         [ 73.2822],
#         [ 93.2797],
#         [122.5677],
#         [105.2604],
#         [128.5153],
#         [ 85.8705],
#         [108.3822],
#         [ 91.5161],
#         [139.2665],
#         [139.2617],
#         [111.3398],
#         [102.6509],
#         [ 72.4255],
#         [ 62.6479],
#         [142.3723],
#         [104.7455],
#         [ 76.2650],
#         [ 52.2022],
#         [ 75.8541],
#         [ 92.7972],
#         [111.6999],
#         [103.0815],
#         [103.9908],
#         [ 95.5559],
#         [125.3951],
#         [124.1145],
#         [100.0103],
#         [102.2442],
#         [ 78.4636],
#         [130.9439],
#         [ 52.1864],
#         [ 79.2834],
#         [ 80.3853],
#         [ 82.6075],
#         [112.9013],
#         [ 56.7095],
#         [134.6640],
#         [133.2270],
#         [147.1945],
#         [ 67.7449],
#         [ 87.6957],
#         [109.3284],
#         [ 76.2018],
#         [137.2035],
#         [ 87.0771],
#         [ 83.4996],
#         [108.8997],
#         [ 53.9730],
#         [ 98.0554],
#         [144.7979],
#         [ 54.2521],
#         [104.6309],
#         [127.8140],
#         [101.9649],
#         [107.2679],
#         [111.4467],
#         [ 67.9675],
#         [ 54.4521],
#         [130.1495],
#         [ 61.0950],
#         [104.7773],
#         [147.4479],
#         [ 72.2004],
#         [100.2873],
#         [ 73.4145],
#         [ 80.2168],
#         [119.4224],
#         [ 62.4641],
#         [ 55.9665],
#         [109.9360],
#         [134.5817],
#         [124.5171],
#         [126.4484],
#         [ 92.1489],
#         [ 93.8071],
#         [148.4803],
#         [108.3762],
#         [109.1878],
#         [142.2674],
#         [137.7342],
#         [117.1939],
#         [117.0930],
#         [108.5860],
#         [103.5191],
#         [147.3047],
#         [ 72.1576],
#         [109.4228],
#         [116.9283],
#         [ 96.3231],
#         [109.5111],
#         [147.5036],
#         [141.1617],
#         [142.2836],
#         [ 54.5252],
#         [ 58.6580],
#         [106.1718],
#         [103.4511],
#         [135.8890],
#         [128.1897],
#         [ 66.6636],
#         [ 58.4877],
#         [ 59.0176],
#         [147.3996],
#         [ 53.4774],
#         [ 84.3961],
#         [116.3980],
#         [125.7789],
#         [117.9872],
#         [ 98.1045],
#         [142.7933],
#         [ 75.4299],
#         [117.4753],
#         [ 59.4801],
#         [ 75.1450],
#         [143.0165],
#         [ 68.1804],
#         [108.8841],
#         [127.4407],
#         [ 54.0845],
#         [139.4023],
#         [ 52.0398],
#         [ 54.0769],
#         [120.8574],
#         [110.5054],
#         [104.5901],
#         [133.4898],
#         [119.9262],
#         [ 94.8616],
#         [ 68.0251],
#         [ 85.7291],
#         [ 77.3204],
#         [121.9503],
#         [109.8165],
#         [137.6191],
#         [ 89.1767],
#         [123.1689],
#         [119.1940],
#         [145.1964],
#         [ 99.4486],
#         [101.5335],
#         [ 64.1441],
#         [ 51.3133],
#         [120.1846],
#         [126.6353],
#         [144.3992],
#         [143.8781],
#         [120.4172],
#         [104.2422],
#         [135.1328],
#         [ 54.7459],
#         [ 81.7170],
#         [101.2612],
#         [100.6569],
#         [ 90.1831],
#         [136.4584],
#         [ 74.5227],
#         [ 51.1405],
#         [109.9712],
#         [ 96.9644],
#         [ 85.0379],
#         [102.4124],
#         [ 53.7898],
#         [ 87.1455],
#         [117.4004],
#         [ 84.9680],
#         [110.0722],
#         [100.5204],
#         [145.5949],
#         [ 83.9513],
#         [138.7368],
#         [ 65.6630],
#         [142.4046],
#         [132.4595],
#         [ 52.8644],
#         [132.6125],
#         [ 86.8241],
#         [120.8516],
#         [ 60.6319],
#         [ 88.4411],
#         [ 93.5977],
#         [ 85.8375],
#         [ 84.0902],
#         [ 68.9268],
#         [111.5305],
#         [117.9519],
#         [126.6835],
#         [ 84.9414],
#         [143.5313],
#         [ 82.0657],
#         [120.4643],
#         [ 86.1112],
#         [ 66.8937],
#         [ 51.7054],
#         [ 59.0462],
#         [ 96.4847],
#         [126.5677],
#         [ 61.1419],
#         [100.7825],
#         [124.9712],
#         [141.2714],
#         [115.5966],
#         [ 50.8120],
#         [ 91.7732],
#         [145.6934],
#         [137.1774],
#         [145.7421],
#         [101.8496],
#         [ 83.9900],
#         [ 54.4305],
#         [135.2440],
#         [ 69.5474],
#         [119.5697],
#         [134.6175],
#         [135.7585],
#         [ 62.3534],
#         [131.1476],
#         [149.6744],
#         [ 74.0584],
#         [ 71.7353],
#         [148.3557],
#         [120.1973],
#         [ 53.4443],
#         [120.2942],
#         [119.0254],
#         [ 88.2755],
#         [106.6166],
#         [ 52.6067],
#         [ 96.0339],
#         [123.8529],
#         [ 78.0663],
#         [ 96.5802],
#         [ 66.9820],
#         [123.0822],
#         [140.8112],
#         [ 86.9601],
#         [122.4277],
#         [115.0167],
#         [ 77.0782],
#         [ 91.6684],
#         [ 54.7505],
#         [ 81.1140],
#         [147.7842],
#         [123.2092],
#         [ 82.2490],
#         [ 98.0780],
#         [ 89.8756],
#         [136.9626],
#         [ 75.6066],
#         [ 76.4065],
#         [146.2772],
#         [ 72.5974],
#         [ 70.1342],
#         [ 69.5361],
#         [144.6640],
#         [132.7592],
#         [ 59.1280],
#         [ 98.1553],
#         [106.5278]])

# %%
# Time -[ between 0 and 2]

a,b = 500 ,1 #dimension of the pytorch tensor to be generated
low_t , high_t = 0, 730 #range of uniform distribution by number of days [0, 2]Years
torch.manual_seed(56) #Fx the values
t_t= torch.randint(low_t, high_t, size= (500,1) )  # https://pytorch.org/docs/stable/generated/torch.randint.html - generates uniformaly integers

t = t_t / 365 # to get a more reliable spread of results

# time for maturity 
#print(t)
Time = t.view(500,1)
#print(Time)

# %%
a,b = 500 ,1 #dimension of the pytorch tensor to be generated
low , high = 0 , 0.01 #range of uniform distribution [0%,1%]
torch.manual_seed(12) #Fx the values
r = torch.distributions.uniform.Uniform(low, high).sample([a,b]) # samples from low and high values. a,b are the dimensions

Rate = r.view(500,1)
print(Rate)
# Out:
# tensor([[4.6569e-03],
#         [2.3277e-03],
#         [4.5272e-03],
#         [5.8711e-03],
#         [4.0864e-03],
#         [1.2717e-03],
#         [6.3728e-03],
#         [2.4206e-03],
#         [7.3119e-03],
#         [7.2244e-03],
#         [1.9924e-03],
#         [6.9483e-03],
#         [5.8300e-03],
#         [6.3183e-03],
#         [5.5589e-03],
#         [1.2625e-03],
#         [9.7903e-03],
#         [8.4427e-03],
#         [1.2559e-03],
#         [4.4562e-03],
#         [6.6006e-03],
#         [5.5381e-04],
#         [1.5729e-03],
#         [8.1367e-03],
#         [7.2163e-03],
#         [2.7173e-03],
#         [3.0030e-03],
#         [6.0994e-03],
#         [5.7837e-03],
#         [6.0834e-03],
#         [4.3386e-03],
#         [8.8131e-03],
#         [3.2163e-03],
#         [2.6044e-03],
#         [2.5662e-03],
#         [1.8722e-03],
#         [6.4234e-03],
#         [1.7856e-03],
#         [1.4349e-03],
#         [7.4904e-03],
#         [7.2748e-03],
#         [1.6413e-03],
#         [3.2731e-03],
#         [1.2394e-03],
#         [6.1380e-03],
#         [4.5347e-03],
#         [7.6589e-03],
#         [1.7998e-03],
#         [3.3378e-03],
#         [9.5258e-03],
#         [8.9188e-03],
#         [9.8594e-03],
#         [6.3482e-03],
#         [8.8115e-03],
#         [9.3908e-03],
#         [1.1733e-03],
#         [1.3422e-03],
#         [9.4047e-03],
#         [6.8025e-03],
#         [5.5559e-03],
#         [8.7132e-03],
#         [7.8215e-04],
#         [8.5778e-03],
#         [7.5400e-03],
#         [6.6977e-03],
#         [5.8174e-03],
#         [3.8287e-03],
#         [7.1626e-03],
#         [8.9302e-03],
#         [5.5965e-03],
#         [2.8026e-03],
#         [2.4760e-03],
#         [4.7377e-03],
#         [1.3057e-03],
#         [2.0237e-03],
#         [6.3868e-03],
#         [9.9918e-04],
#         [9.6145e-03],
#         [5.3495e-03],
#         [7.1406e-03],
#         [5.6170e-03],
#         [9.3177e-04],
#         [7.5537e-03],
#         [2.4570e-03],
#         [4.5643e-03],
#         [7.5540e-03],
#         [4.2481e-03],
#         [8.8401e-03],
#         [3.2807e-03],
#         [8.1618e-03],
#         [5.5743e-03],
#         [8.0262e-03],
#         [5.6611e-03],
#         [2.6652e-03],
#         [6.7312e-03],
#         [6.5486e-03],
#         [1.7007e-03],
#         [1.1221e-03],
#         [3.0764e-05],
#         [9.9427e-03],
#         [5.7380e-03],
#         [5.5909e-03],
#         [5.2530e-03],
#         [3.0211e-03],
#         [8.6720e-03],
#         [8.2054e-03],
#         [1.4439e-03],
#         [7.1165e-03],
#         [8.4354e-03],
#         [4.5909e-03],
#         [5.3825e-03],
#         [5.9378e-03],
#         [8.5118e-04],
#         [1.7838e-03],
#         [9.5099e-03],
#         [2.6122e-04],
#         [5.9063e-03],
#         [1.6631e-04],
#         [3.4400e-03],
#         [4.3865e-03],
#         [5.3556e-03],
#         [2.5917e-03],
#         [7.0026e-03],
#         [6.0630e-03],
#         [8.2040e-04],
#         [5.4303e-03],
#         [9.4201e-03],
#         [9.1870e-03],
#         [2.6959e-03],
#         [7.8865e-03],
#         [1.4075e-03],
#         [9.5172e-03],
#         [6.7836e-03],
#         [6.7655e-03],
#         [1.2871e-03],
#         [3.2810e-03],
#         [5.4226e-04],
#         [7.4241e-03],
#         [7.9089e-04],
#         [3.0929e-03],
#         [4.5903e-03],
#         [7.0398e-03],
#         [6.3120e-03],
#         [6.5052e-03],
#         [8.9198e-03],
#         [5.1193e-03],
#         [4.4257e-03],
#         [3.0880e-03],
#         [3.7612e-03],
#         [9.1995e-04],
#         [8.1285e-03],
#         [9.5422e-03],
#         [8.0833e-03],
#         [7.4171e-03],
#         [3.5903e-03],
#         [8.8538e-04],
#         [9.7467e-03],
#         [3.4973e-03],
#         [3.0590e-03],
#         [1.2533e-03],
#         [1.7069e-03],
#         [6.0185e-03],
#         [7.9108e-03],
#         [6.0712e-04],
#         [5.9254e-04],
#         [4.3266e-03],
#         [8.0525e-04],
#         [8.9186e-03],
#         [5.0915e-03],
#         [1.3726e-03],
#         [6.2866e-03],
#         [8.6563e-03],
#         [5.7241e-03],
#         [1.3932e-03],
#         [5.8195e-03],
#         [1.2443e-03],
#         [7.8594e-03],
#         [4.5167e-03],
#         [6.1291e-03],
#         [4.3318e-03],
#         [9.8860e-04],
#         [6.3860e-03],
#         [9.2534e-03],
#         [4.0014e-03],
#         [3.1829e-03],
#         [9.3000e-04],
#         [4.4078e-03],
#         [9.8530e-03],
#         [3.6548e-03],
#         [3.5212e-03],
#         [8.4172e-03],
#         [9.2552e-04],
#         [4.2649e-03],
#         [3.3510e-03],
#         [4.8541e-03],
#         [1.7951e-03],
#         [5.1280e-03],
#         [5.6453e-03],
#         [5.8909e-03],
#         [2.0159e-03],
#         [6.1555e-03],
#         [6.3055e-04],
#         [5.0992e-03],
#         [5.5482e-03],
#         [3.6661e-03],
#         [4.5996e-03],
#         [5.0251e-03],
#         [7.6503e-03],
#         [9.4470e-03],
#         [4.7464e-04],
#         [8.8766e-03],
#         [6.7043e-03],
#         [9.8796e-03],
#         [9.4636e-03],
#         [3.2712e-03],
#         [2.6744e-03],
#         [8.3670e-03],
#         [7.8903e-03],
#         [9.1555e-03],
#         [2.8732e-03],
#         [6.2484e-03],
#         [3.2498e-03],
#         [1.2889e-03],
#         [8.1177e-03],
#         [6.0549e-03],
#         [9.0028e-03],
#         [7.5151e-03],
#         [1.5053e-03],
#         [2.6780e-03],
#         [6.5432e-03],
#         [8.7755e-03],
#         [8.2581e-04],
#         [9.8060e-03],
#         [8.0983e-03],
#         [4.6112e-03],
#         [2.0913e-04],
#         [2.8920e-03],
#         [8.4564e-03],
#         [6.7140e-03],
#         [5.7798e-03],
#         [7.7958e-04],
#         [2.8130e-04],
#         [6.2821e-04],
#         [5.0141e-03],
#         [4.3218e-03],
#         [2.2069e-03],
#         [9.7490e-03],
#         [1.0015e-04],
#         [2.8268e-04],
#         [6.1235e-04],
#         [2.5306e-03],
#         [5.3462e-03],
#         [3.5515e-03],
#         [5.3734e-03],
#         [8.8138e-03],
#         [1.2175e-03],
#         [2.7122e-03],
#         [9.7523e-03],
#         [3.9152e-03],
#         [3.2165e-03],
#         [8.2584e-03],
#         [9.5770e-03],
#         [3.3790e-03],
#         [1.2776e-03],
#         [9.9339e-03],
#         [9.1984e-03],
#         [6.8936e-03],
#         [5.7207e-03],
#         [4.4163e-03],
#         [2.2116e-03],
#         [4.8856e-04],
#         [9.8939e-03],
#         [6.7223e-03],
#         [9.5460e-03],
#         [9.4945e-03],
#         [5.8301e-04],
#         [6.6746e-03],
#         [1.5353e-03],
#         [8.1107e-03],
#         [9.5678e-03],
#         [9.6629e-03],
#         [8.5742e-03],
#         [6.3713e-03],
#         [3.5372e-03],
#         [6.7270e-03],
#         [2.0756e-03],
#         [4.9396e-03],
#         [7.9779e-03],
#         [1.0282e-03],
#         [5.9092e-03],
#         [8.9574e-03],
#         [6.8857e-03],
#         [6.8447e-03],
#         [6.5575e-03],
#         [2.4951e-03],
#         [7.7200e-03],
#         [7.9632e-03],
#         [3.9875e-03],
#         [5.7039e-04],
#         [4.5957e-03],
#         [7.9565e-03],
#         [5.3598e-03],
#         [7.9190e-03],
#         [2.3655e-03],
#         [2.0126e-03],
#         [1.0809e-03],
#         [1.2545e-03],
#         [5.1568e-03],
#         [2.1058e-03],
#         [1.3525e-03],
#         [3.4714e-03],
#         [6.1840e-03],
#         [2.1194e-03],
#         [5.7274e-03],
#         [8.8733e-04],
#         [7.3244e-03],
#         [2.1630e-03],
#         [9.5457e-03],
#         [9.2192e-03],
#         [1.7541e-03],
#         [9.5285e-04],
#         [9.4797e-03],
#         [3.0853e-03],
#         [4.0150e-03],
#         [4.1848e-03],
#         [8.0866e-03],
#         [5.4796e-04],
#         [2.5711e-03],
#         [8.5941e-04],
#         [6.2539e-03],
#         [1.6981e-03],
#         [9.0549e-03],
#         [9.6344e-03],
#         [8.4477e-04],
#         [7.4867e-03],
#         [1.2881e-03],
#         [1.2998e-03],
#         [4.7148e-03],
#         [2.4830e-03],
#         [6.9088e-03],
#         [8.0008e-03],
#         [4.0990e-03],
#         [4.4038e-03],
#         [9.7962e-03],
#         [9.1916e-03],
#         [3.9974e-03],
#         [4.2370e-03],
#         [5.3191e-03],
#         [6.5928e-03],
#         [5.7228e-03],
#         [1.1069e-03],
#         [3.2478e-03],
#         [3.1500e-03],
#         [2.9880e-03],
#         [5.2846e-03],
#         [3.3306e-03],
#         [1.0687e-03],
#         [2.5909e-04],
#         [4.1681e-04],
#         [8.2868e-03],
#         [9.8744e-03],
#         [7.7010e-03],
#         [9.3810e-03],
#         [9.1231e-03],
#         [6.5881e-04],
#         [5.3043e-03],
#         [3.8470e-03],
#         [1.7885e-03],
#         [1.0916e-03],
#         [7.0954e-03],
#         [7.8134e-03],
#         [8.6352e-03],
#         [4.9894e-03],
#         [7.7390e-03],
#         [9.5098e-03],
#         [4.9793e-03],
#         [7.3731e-03],
#         [3.6785e-03],
#         [2.4160e-03],
#         [8.5149e-03],
#         [7.2802e-03],
#         [3.1832e-03],
#         [5.1328e-03],
#         [1.2626e-03],
#         [5.6175e-03],
#         [7.4359e-03],
#         [6.6080e-03],
#         [1.8972e-03],
#         [4.5415e-03],
#         [7.5261e-03],
#         [6.6819e-03],
#         [9.3686e-03],
#         [9.3678e-03],
#         [5.6835e-03],
#         [1.7040e-03],
#         [7.9508e-03],
#         [8.1406e-03],
#         [3.0941e-03],
#         [7.5644e-03],
#         [7.4587e-03],
#         [1.3149e-03],
#         [3.8895e-03],
#         [2.8641e-03],
#         [5.5825e-03],
#         [2.3895e-03],
#         [3.5343e-03],
#         [7.2948e-03],
#         [7.8438e-03],
#         [8.9346e-04],
#         [3.4920e-03],
#         [8.4655e-03],
#         [8.5957e-03],
#         [3.9640e-03],
#         [1.9857e-05],
#         [6.0708e-03],
#         [8.3113e-03],
#         [9.0259e-03],
#         [1.6266e-03],
#         [1.3741e-03],
#         [2.6306e-03],
#         [6.0025e-03],
#         [2.3597e-04],
#         [1.6939e-03],
#         [4.5020e-03],
#         [4.5870e-03],
#         [4.6820e-03],
#         [4.0316e-03],
#         [5.4608e-03],
#         [2.0226e-03],
#         [8.4080e-03],
#         [8.4062e-03],
#         [2.2259e-03],
#         [7.2899e-03],
#         [5.9691e-03],
#         [8.7318e-03],
#         [3.9709e-03],
#         [6.4037e-03],
#         [5.0106e-03],
#         [3.3210e-03],
#         [8.8398e-03],
#         [1.1628e-03],
#         [1.4018e-04],
#         [6.7419e-03],
#         [6.2346e-03],
#         [6.4588e-03],
#         [6.8005e-03],
#         [7.2138e-03],
#         [7.2217e-03],
#         [1.3160e-03],
#         [7.4927e-03],
#         [8.0705e-03],
#         [2.5520e-03],
#         [6.1733e-03],
#         [8.4148e-03],
#         [6.8184e-03],
#         [5.2352e-03],
#         [2.4425e-03],
#         [9.1327e-03],
#         [8.1743e-03],
#         [6.9133e-03],
#         [1.9904e-03],
#         [6.7804e-03],
#         [6.3000e-03],
#         [2.3593e-03],
#         [4.1635e-03],
#         [2.9885e-04],
#         [9.2221e-03],
#         [5.2018e-03],
#         [7.6305e-03],
#         [4.4355e-03],
#         [5.4922e-03],
#         [7.3290e-03],
#         [8.1384e-03],
#         [4.8371e-03],
#         [1.4123e-03],
#         [1.8921e-03],
#         [6.1608e-03],
#         [4.3759e-03],
#         [4.9801e-03],
#         [9.1514e-03],
#         [1.1688e-03],
#         [8.6735e-03],
#         [3.9166e-03],
#         [4.7575e-03],
#         [2.4471e-03],
#         [3.5511e-03],
#         [6.5328e-03],
#         [1.6027e-03],
#         [9.2769e-03],
#         [6.1159e-03],
#         [8.3130e-03],
#         [3.4551e-03],
#         [8.8495e-03],
#         [5.6870e-03],
#         [4.6102e-03],
#         [7.0284e-03],
#         [1.0693e-03],
#         [2.7279e-03],
#         [1.8035e-03],
#         [2.5701e-03]])

# %%
# volatility 

a,b = 500 ,1 #dimension of the pytorch tensor to be generated
low , high =  0.01, 0.5 #range of uniform distribution [1%,50%]
torch.manual_seed(30) #Fx the values
si = torch.distributions.uniform.Uniform(low, high).sample([a,b]) # samples from low and high values. a,b are the dimensions
# whenevr we want to fix a distribution we just use torch.manual_seed to fix the distribution.
Sigma = si.view(500,1)
print(Sigma) # 500 samples by 1 column
# Out:
# tensor([[0.4514],
#         [0.3757],
#         [0.2411],
#         [0.4381],
#         [0.3727],
#         [0.3942],
#         [0.4483],
#         [0.3157],
#         [0.2195],
#         [0.4226],
#         [0.3753],
#         [0.3129],
#         [0.4452],
#         [0.2122],
#         [0.0957],
#         [0.1779],
#         [0.4695],
#         [0.0302],
#         [0.0652],
#         [0.3516],
#         [0.4392],
#         [0.1650],
#         [0.1565],
#         [0.3935],
#         [0.3300],
#         [0.2168],
#         [0.1643],
#         [0.2949],
#         [0.0422],
#         [0.1794],
#         [0.4824],
#         [0.1320],
#         [0.0675],
#         [0.3004],
#         [0.2617],
#         [0.2919],
#         [0.1110],
#         [0.1941],
#         [0.0984],
#         [0.2388],
#         [0.0343],
#         [0.2921],
#         [0.0825],
#         [0.1794],
#         [0.1159],
#         [0.1430],
#         [0.4850],
#         [0.4166],
#         [0.0313],
#         [0.2637],
#         [0.1704],
#         [0.2162],
#         [0.1260],
#         [0.1823],
#         [0.1882],
#         [0.2323],
#         [0.4098],
#         [0.4110],
#         [0.2561],
#         [0.0781],
#         [0.3467],
#         [0.1347],
#         [0.4749],
#         [0.2663],
#         [0.4695],
#         [0.0810],
#         [0.4652],
#         [0.0675],
#         [0.4289],
#         [0.3207],
#         [0.2545],
#         [0.2627],
#         [0.4128],
#         [0.1448],
#         [0.2218],
#         [0.4398],
#         [0.4658],
#         [0.3817],
#         [0.3237],
#         [0.4903],
#         [0.3417],
#         [0.3773],
#         [0.3409],
#         [0.3452],
#         [0.1534],
#         [0.2437],
#         [0.2193],
#         [0.1330],
#         [0.3613],
#         [0.0485],
#         [0.3582],
#         [0.3870],
#         [0.4234],
#         [0.2791],
#         [0.3323],
#         [0.2974],
#         [0.3894],
#         [0.0725],
#         [0.1000],
#         [0.2808],
#         [0.4370],
#         [0.4105],
#         [0.4037],
#         [0.4038],
#         [0.4402],
#         [0.4757],
#         [0.2445],
#         [0.1365],
#         [0.3571],
#         [0.4800],
#         [0.1824],
#         [0.4477],
#         [0.2060],
#         [0.0366],
#         [0.2494],
#         [0.1351],
#         [0.1299],
#         [0.3772],
#         [0.3144],
#         [0.3131],
#         [0.3775],
#         [0.0983],
#         [0.2545],
#         [0.2297],
#         [0.1275],
#         [0.3867],
#         [0.2106],
#         [0.0500],
#         [0.4216],
#         [0.3850],
#         [0.1226],
#         [0.3378],
#         [0.4768],
#         [0.1791],
#         [0.3353],
#         [0.1584],
#         [0.4796],
#         [0.2996],
#         [0.3502],
#         [0.0724],
#         [0.1490],
#         [0.0476],
#         [0.1120],
#         [0.4510],
#         [0.1701],
#         [0.1527],
#         [0.3847],
#         [0.4342],
#         [0.4463],
#         [0.3818],
#         [0.2177],
#         [0.2201],
#         [0.3777],
#         [0.4505],
#         [0.3170],
#         [0.0834],
#         [0.1341],
#         [0.2871],
#         [0.2142],
#         [0.3664],
#         [0.2620],
#         [0.1639],
#         [0.2722],
#         [0.1486],
#         [0.1033],
#         [0.1105],
#         [0.1249],
#         [0.4994],
#         [0.2149],
#         [0.1513],
#         [0.2327],
#         [0.2158],
#         [0.2059],
#         [0.1668],
#         [0.1734],
#         [0.0600],
#         [0.2658],
#         [0.0307],
#         [0.1379],
#         [0.4661],
#         [0.1875],
#         [0.0569],
#         [0.1537],
#         [0.3013],
#         [0.4840],
#         [0.2221],
#         [0.2095],
#         [0.3012],
#         [0.3120],
#         [0.0776],
#         [0.0588],
#         [0.0382],
#         [0.1720],
#         [0.1364],
#         [0.0211],
#         [0.3436],
#         [0.4875],
#         [0.2320],
#         [0.2742],
#         [0.1811],
#         [0.2891],
#         [0.1360],
#         [0.2758],
#         [0.0996],
#         [0.4042],
#         [0.0511],
#         [0.3039],
#         [0.3252],
#         [0.4755],
#         [0.4783],
#         [0.0382],
#         [0.0754],
#         [0.4075],
#         [0.4081],
#         [0.2029],
#         [0.0967],
#         [0.4788],
#         [0.3748],
#         [0.0234],
#         [0.3609],
#         [0.3737],
#         [0.4136],
#         [0.1079],
#         [0.3032],
#         [0.2389],
#         [0.0380],
#         [0.3466],
#         [0.2889],
#         [0.0223],
#         [0.4493],
#         [0.4873],
#         [0.2818],
#         [0.4851],
#         [0.4406],
#         [0.3767],
#         [0.0210],
#         [0.4878],
#         [0.2608],
#         [0.2984],
#         [0.4238],
#         [0.3766],
#         [0.1922],
#         [0.0199],
#         [0.1106],
#         [0.0981],
#         [0.3861],
#         [0.2840],
#         [0.3211],
#         [0.1657],
#         [0.1768],
#         [0.1150],
#         [0.2666],
#         [0.1904],
#         [0.0397],
#         [0.2065],
#         [0.0180],
#         [0.0573],
#         [0.1098],
#         [0.3864],
#         [0.3301],
#         [0.1655],
#         [0.2990],
#         [0.2668],
#         [0.3966],
#         [0.3897],
#         [0.2258],
#         [0.4724],
#         [0.2284],
#         [0.2900],
#         [0.2423],
#         [0.3868],
#         [0.1910],
#         [0.4313],
#         [0.4511],
#         [0.4943],
#         [0.4486],
#         [0.1539],
#         [0.0370],
#         [0.2381],
#         [0.2066],
#         [0.1282],
#         [0.0954],
#         [0.1868],
#         [0.1222],
#         [0.0537],
#         [0.3309],
#         [0.3321],
#         [0.4771],
#         [0.4894],
#         [0.0162],
#         [0.3052],
#         [0.4868],
#         [0.4560],
#         [0.0232],
#         [0.4770],
#         [0.3245],
#         [0.2194],
#         [0.2071],
#         [0.3608],
#         [0.1502],
#         [0.0577],
#         [0.0643],
#         [0.3298],
#         [0.4225],
#         [0.1324],
#         [0.2380],
#         [0.2301],
#         [0.4547],
#         [0.2385],
#         [0.1050],
#         [0.2420],
#         [0.2405],
#         [0.2301],
#         [0.0953],
#         [0.4756],
#         [0.3905],
#         [0.3200],
#         [0.1249],
#         [0.3356],
#         [0.1937],
#         [0.3010],
#         [0.0791],
#         [0.4800],
#         [0.3325],
#         [0.1232],
#         [0.2940],
#         [0.3072],
#         [0.2847],
#         [0.1840],
#         [0.1715],
#         [0.4908],
#         [0.1716],
#         [0.4823],
#         [0.1621],
#         [0.0289],
#         [0.3950],
#         [0.0553],
#         [0.0792],
#         [0.4489],
#         [0.4930],
#         [0.3430],
#         [0.4128],
#         [0.4779],
#         [0.3431],
#         [0.2605],
#         [0.2681],
#         [0.3659],
#         [0.3504],
#         [0.2351],
#         [0.4055],
#         [0.1290],
#         [0.3247],
#         [0.4861],
#         [0.0241],
#         [0.0475],
#         [0.2643],
#         [0.2280],
#         [0.1962],
#         [0.2527],
#         [0.3038],
#         [0.2147],
#         [0.3503],
#         [0.2016],
#         [0.3750],
#         [0.2856],
#         [0.3865],
#         [0.2009],
#         [0.4044],
#         [0.0611],
#         [0.3139],
#         [0.0160],
#         [0.2178],
#         [0.1030],
#         [0.0628],
#         [0.1347],
#         [0.3637],
#         [0.1304],
#         [0.3124],
#         [0.2332],
#         [0.3612],
#         [0.0502],
#         [0.2526],
#         [0.0913],
#         [0.1230],
#         [0.1814],
#         [0.4366],
#         [0.0167],
#         [0.2709],
#         [0.0273],
#         [0.2689],
#         [0.0174],
#         [0.4551],
#         [0.0714],
#         [0.3105],
#         [0.1500],
#         [0.3334],
#         [0.3277],
#         [0.0998],
#         [0.1143],
#         [0.2409],
#         [0.4020],
#         [0.4942],
#         [0.1752],
#         [0.3539],
#         [0.1475],
#         [0.0977],
#         [0.4140],
#         [0.1110],
#         [0.4274],
#         [0.2888],
#         [0.0519],
#         [0.3019],
#         [0.2090],
#         [0.1231],
#         [0.0174],
#         [0.2936],
#         [0.0393],
#         [0.4037],
#         [0.3912],
#         [0.1453],
#         [0.4318],
#         [0.1670],
#         [0.0659],
#         [0.2492],
#         [0.3730],
#         [0.1423],
#         [0.3575],
#         [0.3084],
#         [0.1660],
#         [0.2246],
#         [0.3237],
#         [0.1751],
#         [0.0364],
#         [0.3551],
#         [0.3833],
#         [0.1141],
#         [0.0914],
#         [0.1116],
#         [0.4475],
#         [0.0462],
#         [0.3775],
#         [0.3229],
#         [0.2980],
#         [0.1301],
#         [0.0632],
#         [0.0313],
#         [0.0877],
#         [0.0867],
#         [0.1798],
#         [0.1251],
#         [0.2049],
#         [0.2178],
#         [0.4660],
#         [0.0655],
#         [0.4221],
#         [0.0650],
#         [0.2277],
#         [0.3825],
#         [0.1430],
#         [0.1047],
#         [0.3004],
#         [0.2258],
#         [0.3615],
#         [0.1670],
#         [0.4317],
#         [0.2063],
#         [0.0192],
#         [0.4166],
#         [0.4669],
#         [0.4139],
#         [0.2352],
#         [0.1498],
#         [0.0953],
#         [0.0908],
#         [0.1015],
#         [0.3043],
#         [0.2694],
#         [0.1313],
#         [0.2167],
#         [0.3122],
#         [0.4246],
#         [0.4496],
#         [0.4540],
#         [0.3288],
#         [0.0663],
#         [0.3741],
#         [0.1717],
#         [0.3613],
#         [0.1061],
#         [0.3046],
#         [0.0804],
#         [0.0979],
#         [0.0169],
#         [0.1593],
#         [0.3960],
#         [0.0487],
#         [0.2548],
#         [0.4566],
#         [0.2504],
#         [0.3334]])

# %%
# Stock, Time, Rate ,Sigma -> 4 features (variables)
# Strike
# https://discuss.pytorch.org/t/tensor-stack-or-concatenate/34331/6 - column and concatinate 

X = torch.column_stack([Stock, Time, Rate, Sigma])
print(X)
print(X.shape) # m x n matrix
# Out:
# tensor([[1.1180e+02, 7.0959e-01, 4.6569e-03, 4.5136e-01],
#         [5.6869e+01, 1.8685e+00, 2.3277e-03, 3.7572e-01],
#         [8.8928e+01, 1.3342e+00, 4.5272e-03, 2.4109e-01],
#         ...,
#         [5.9128e+01, 1.7836e+00, 2.7279e-03, 4.5660e-01],
#         [9.8155e+01, 7.0685e-01, 1.8035e-03, 2.5040e-01],
#         [1.0653e+02, 1.7068e+00, 2.5701e-03, 3.3336e-01]])
# torch.Size([500, 4])

# %%
X.requires_grad_(True) # graident for backprop activated with requires_grad true
X.retain_grad() # leaf tensor is a root of the tree 

print(X.shape)
# Out:
# torch.Size([500, 4])

# %%
# non- divident paying asset. 
# P + S - C = K * e^-r(T-t)
# Set strike price = 100

Strike = 100 # fixed hyper paramters. 

# Our case this is a fixed paramter.

# %%
def euro_vanilla_call(x):
  d1 = (torch.log(x[0] / Strike) + (x[2] + 0.5 * x[3] ** 2) * x[1]) / (x[3] * torch.sqrt(x[1]))
  d2 = (torch.log(x[0] / Strike) + (x[2] - 0.5 * x[3] ** 2) * x[1]) / (x[3] * torch.sqrt(x[1]))
    
  call = (x[0] * torch.distributions.normal.Normal(0,1).cdf(d1) - Strike * torch.exp(-x[2] * x[1]) * torch.distributions.normal.Normal(0,1).cdf(d2))

  return call
# https://pytorch.org/docs/stable/distributions.html - Normal( loc,scale)
#https://www.itl.nist.gov/div898/handbook/eda/section3/eda364.htm - loc and scale the same as mean and standard deviation.
# https://pytorch.org/docs/stable/generated/torch.log.html - returns natrual logarithem
# https://pytorch.org/docs/stable/generated/torch.sqrt.html - returns squart root

# %%
y = torch.zeros(size = (500 , 1)) # samples

for i in range(X.shape[0]):
  y[i] = euro_vanilla_call(X[i]) # runs through each row computation. 

print(y) # M samples dimension all in all.
# Out:
# tensor([[ 2.2721e+01],
#         [ 2.6445e+00],
#         [ 6.0082e+00],
#         [ 1.1345e+00],
#         [ 1.3856e+01],
#         [ 4.1641e+00],
#         [ 1.2586e+01],
#         [ 6.4811e+00],
#         [ 1.7054e+01],
#         [ 4.9546e+01],
#         [ 5.2213e-01],
#         [ 1.2441e+01],
#         [ 2.4887e+01],
#         [ 5.0325e+01],
#         [ 1.1689e+01],
#         [ 9.2247e+00],
#         [ 3.5610e+01],
#         [ 0.0000e+00],
#         [ 1.4142e-05],
#         [ 1.5222e+01],
#         [ 3.1163e+01],
#         [ 9.1199e+00],
#         [ 0.0000e+00],
#         [ 5.0606e+00],
#         [ 6.1015e-01],
#         [ 2.5259e+00],
#         [ 3.0119e-04],
#         [ 2.3009e+01],
#         [ 2.5393e+01],
#         [ 3.3681e-02],
#         [ 1.7437e+01],
#         [ 3.5364e-02],
#         [ 4.3309e-03],
#         [ 5.5197e+00],
#         [ 8.1241e+00],
#         [ 3.1608e+01],
#         [ 1.9335e+01],
#         [ 2.7152e+01],
#         [ 7.7752e-04],
#         [ 3.7977e+01],
#         [ 3.5301e+01],
#         [ 1.7973e-02],
#         [ 1.8367e-05],
#         [ 8.9325e-01],
#         [ 9.8600e+00],
#         [-1.3684e-06],
#         [ 0.0000e+00],
#         [ 3.2383e+01],
#         [ 0.0000e+00],
#         [ 2.6717e+01],
#         [ 3.9580e+00],
#         [ 3.7449e+01],
#         [ 2.4446e+01],
#         [ 4.7299e+01],
#         [ 8.0716e+00],
#         [ 2.6576e+00],
#         [ 1.6423e-02],
#         [ 1.1538e+01],
#         [ 2.8452e-01],
#         [ 0.0000e+00],
#         [ 1.1676e+00],
#         [ 4.7218e+00],
#         [ 3.4604e+01],
#         [ 4.3360e+01],
#         [ 1.2991e+01],
#         [ 5.0267e+00],
#         [ 0.0000e+00],
#         [ 2.7286e+00],
#         [ 7.9617e+00],
#         [ 6.4969e+00],
#         [ 6.9146e-06],
#         [ 1.9393e+01],
#         [ 5.1186e+01],
#         [ 3.2869e+01],
#         [ 5.6599e+00],
#         [ 2.9384e+01],
#         [ 1.0092e+01],
#         [ 3.5667e+01],
#         [ 3.7519e+01],
#         [ 1.7651e+00],
#         [ 3.1294e+01],
#         [ 6.5131e-02],
#         [ 3.5743e+01],
#         [ 3.7164e+01],
#         [ 4.6496e+01],
#         [ 1.6375e+01],
#         [ 1.8229e+01],
#         [ 2.3730e+01],
#         [ 5.1924e+01],
#         [ 4.6979e+01],
#         [ 4.0193e+00],
#         [ 4.8789e+01],
#         [ 4.3932e+01],
#         [ 1.1861e+01],
#         [ 5.0110e+01],
#         [ 5.9530e-01],
#         [ 2.3510e+01],
#         [ 0.0000e+00],
#         [ 1.0085e-05],
#         [ 5.0497e+01],
#         [ 4.2984e+00],
#         [ 9.2994e+00],
#         [ 4.8631e+01],
#         [ 5.1178e+00],
#         [ 2.7095e+01],
#         [ 8.2654e-01],
#         [ 5.5484e-01],
#         [ 2.4360e-05],
#         [ 3.0788e+01],
#         [ 2.0376e+01],
#         [ 2.5944e+01],
#         [ 2.6889e+01],
#         [ 9.8271e-03],
#         [ 3.1399e+01],
#         [ 4.3841e+01],
#         [ 4.4609e+01],
#         [ 1.5876e+01],
#         [ 9.5195e+00],
#         [ 3.6845e+01],
#         [ 1.7797e+01],
#         [ 1.6826e+01],
#         [ 2.4287e+00],
#         [ 3.1320e+01],
#         [ 2.0043e+01],
#         [ 1.2947e-01],
#         [ 4.4045e+01],
#         [ 2.4800e+00],
#         [ 4.6169e+01],
#         [ 9.5953e+00],
#         [ 4.5866e+00],
#         [ 4.2276e+00],
#         [ 3.7272e+01],
#         [ 3.9069e+01],
#         [ 8.2948e+00],
#         [ 5.1220e-01],
#         [ 5.9767e-01],
#         [ 1.0196e+01],
#         [ 7.0816e-01],
#         [ 1.9749e+01],
#         [ 2.5807e+00],
#         [ 2.5530e+01],
#         [ 1.8545e+01],
#         [ 3.5915e+01],
#         [ 1.9321e+01],
#         [ 2.1892e-02],
#         [ 2.5084e+00],
#         [ 8.6649e+00],
#         [ 2.4384e+01],
#         [ 7.9638e+00],
#         [ 4.3121e+01],
#         [ 3.1272e+01],
#         [ 3.2924e+01],
#         [ 1.8447e+01],
#         [ 2.0682e+00],
#         [ 4.8064e+01],
#         [ 1.1942e+00],
#         [ 2.0201e-01],
#         [ 3.1990e+01],
#         [ 4.3830e+01],
#         [ 1.2262e-02],
#         [ 1.3450e+01],
#         [ 2.8783e+01],
#         [ 3.2658e+01],
#         [ 0.0000e+00],
#         [ 1.6279e-06],
#         [ 2.1296e+01],
#         [ 1.3790e-01],
#         [ 1.0744e+01],
#         [ 1.1187e+00],
#         [ 1.1436e+01],
#         [ 6.0830e+00],
#         [ 2.2974e+01],
#         [ 3.1641e+01],
#         [ 7.0282e-04],
#         [-3.3572e-07],
#         [ 2.5611e-03],
#         [ 3.2413e+01],
#         [-6.1244e-07],
#         [ 1.5972e+01],
#         [ 3.6554e+01],
#         [ 1.3295e+00],
#         [ 8.7442e-04],
#         [ 4.9102e+01],
#         [ 4.1757e-01],
#         [ 7.2757e+00],
#         [ 3.4677e-05],
#         [ 7.4413e-01],
#         [ 1.9261e-01],
#         [ 5.1981e+01],
#         [ 2.9339e-05],
#         [ 3.7810e+01],
#         [ 4.9609e-01],
#         [ 1.3254e+01],
#         [ 1.0997e+01],
#         [ 4.7507e+01],
#         [ 4.9055e+01],
#         [ 4.2746e+01],
#         [ 3.6284e+01],
#         [ 3.5700e+00],
#         [ 2.2425e+01],
#         [ 2.4099e+01],
#         [ 2.5489e+01],
#         [ 7.7592e+00],
#         [ 4.0422e-03],
#         [ 1.2029e+01],
#         [ 4.6937e+01],
#         [ 2.3034e+01],
#         [ 1.9545e+01],
#         [ 4.1824e-03],
#         [ 3.4041e+01],
#         [ 0.0000e+00],
#         [ 7.4964e-01],
#         [ 3.3430e+01],
#         [ 1.2046e+00],
#         [ 5.9525e+00],
#         [ 3.5006e+01],
#         [ 8.4488e+00],
#         [ 8.3175e+00],
#         [ 0.0000e+00],
#         [ 9.2232e+00],
#         [ 5.0491e+01],
#         [ 1.4508e+01],
#         [ 3.0053e+01],
#         [ 1.7991e+01],
#         [ 7.4437e+00],
#         [ 1.7420e+01],
#         [ 2.0577e+01],
#         [ 5.3489e+00],
#         [ 1.2179e+01],
#         [ 2.1829e+01],
#         [ 6.2160e+01],
#         [ 3.3498e+01],
#         [ 5.7522e+00],
#         [ 8.8790e+00],
#         [ 1.6754e+00],
#         [ 2.3712e+01],
#         [ 4.3164e+01],
#         [ 2.1128e-01],
#         [ 1.4714e+01],
#         [ 7.7010e+00],
#         [ 2.4940e+01],
#         [ 7.8247e+00],
#         [ 0.0000e+00],
#         [ 1.2937e+00],
#         [ 2.2736e+01],
#         [ 2.3109e+01],
#         [ 2.8592e+01],
#         [ 6.3280e+00],
#         [ 1.4324e+01],
#         [ 3.0993e+00],
#         [ 3.9515e+01],
#         [ 4.2390e+01],
#         [ 1.5172e+01],
#         [ 2.7623e+00],
#         [ 1.5693e+00],
#         [ 0.0000e+00],
#         [ 4.2565e+01],
#         [ 8.1841e+00],
#         [ 3.4467e+00],
#         [ 6.3089e-04],
#         [ 0.0000e+00],
#         [ 9.0134e+00],
#         [ 1.6660e+01],
#         [ 8.1734e+00],
#         [ 1.1644e+01],
#         [ 9.0140e+00],
#         [ 3.5914e+01],
#         [ 2.8346e+01],
#         [ 5.1452e+00],
#         [ 1.2161e+01],
#         [ 1.0118e+01],
#         [ 3.3898e+01],
#         [ 5.9361e-05],
#         [ 9.2695e-01],
#         [ 1.0417e+01],
#         [ 1.4048e+01],
#         [ 1.5538e+01],
#         [ 0.0000e+00],
#         [ 3.6627e+01],
#         [ 3.3450e+01],
#         [ 4.8163e+01],
#         [ 2.3531e-03],
#         [ 2.8289e-01],
#         [ 1.0045e+01],
#         [ 0.0000e+00],
#         [ 4.3800e+01],
#         [ 5.8888e+00],
#         [ 1.0413e+01],
#         [ 2.1901e+01],
#         [ 0.0000e+00],
#         [ 1.1695e+01],
#         [ 5.5176e+01],
#         [ 0.0000e+00],
#         [ 5.3176e+00],
#         [ 4.5960e+01],
#         [ 9.1607e+00],
#         [ 1.7525e+01],
#         [ 1.8219e+01],
#         [ 7.5777e-03],
#         [-1.3499e-06],
#         [ 3.0987e+01],
#         [ 0.0000e+00],
#         [ 1.6827e+01],
#         [ 5.2700e+01],
#         [ 2.2262e-01],
#         [ 1.2232e+01],
#         [ 1.0349e+00],
#         [ 3.0364e+00],
#         [ 2.1759e+01],
#         [ 2.2554e-06],
#         [ 3.4640e-02],
#         [ 1.6791e+01],
#         [ 3.6794e+01],
#         [ 2.4592e+01],
#         [ 3.1258e+01],
#         [ 1.2197e+01],
#         [ 1.0943e+01],
#         [ 4.9974e+01],
#         [ 2.1283e+01],
#         [ 1.2509e+01],
#         [ 4.6826e+01],
#         [ 3.8232e+01],
#         [ 3.5780e+01],
#         [ 2.4925e+01],
#         [ 1.0665e+01],
#         [ 1.8474e+01],
#         [ 4.8183e+01],
#         [ 6.0387e-01],
#         [ 1.1854e+01],
#         [ 2.0480e+01],
#         [ 2.3143e+01],
#         [ 1.5398e+01],
#         [ 5.3534e+01],
#         [ 4.1377e+01],
#         [ 4.3675e+01],
#         [ 1.2336e-01],
#         [ 0.0000e+00],
#         [ 6.1783e+00],
#         [ 1.9556e+01],
#         [ 4.4036e+01],
#         [ 3.0358e+01],
#         [ 3.2269e-01],
#         [ 5.4659e-01],
#         [ 1.4032e+00],
#         [ 5.0398e+01],
#         [ 2.4596e-03],
#         [ 4.6948e+00],
#         [ 1.7470e+01],
#         [ 2.7893e+01],
#         [ 3.1299e+01],
#         [ 1.7995e+00],
#         [ 4.4331e+01],
#         [ 1.1868e-01],
#         [ 1.7670e+01],
#         [ 0.0000e+00],
#         [ 5.5270e-01],
#         [ 4.5339e+01],
#         [ 6.3822e-01],
#         [ 1.2851e+01],
#         [ 3.2148e+01],
#         [ 1.8068e-04],
#         [ 3.9987e+01],
#         [ 3.9825e-03],
#         [ 4.7978e-02],
#         [ 2.4396e+01],
#         [ 2.3826e+01],
#         [ 1.4376e+01],
#         [ 4.4042e+01],
#         [ 1.9967e+01],
#         [ 1.4511e+01],
#         [ 0.0000e+00],
#         [ 1.3337e+00],
#         [ 1.3013e-01],
#         [ 2.3094e+01],
#         [ 1.3534e+01],
#         [ 4.7756e+01],
#         [ 2.7109e+00],
#         [ 3.3304e+01],
#         [ 2.0391e+01],
#         [ 5.0988e+01],
#         [ 2.5135e+00],
#         [ 1.3313e+01],
#         [ 7.2661e-05],
#         [-1.1165e-06],
#         [ 2.4168e+01],
#         [ 3.0532e+01],
#         [ 4.4829e+01],
#         [ 4.7819e+01],
#         [ 2.0775e+01],
#         [ 1.6895e+01],
#         [ 3.5908e+01],
#         [ 1.4107e+00],
#         [ 9.7128e-02],
#         [ 1.6675e+01],
#         [ 5.8705e+00],
#         [ 1.2408e+01],
#         [ 4.2866e+01],
#         [ 3.0731e-02],
#         [ 1.7769e-07],
#         [ 1.5985e+01],
#         [ 1.5861e+01],
#         [ 1.7658e+01],
#         [ 8.2031e+00],
#         [ 1.9120e-01],
#         [ 7.5862e-01],
#         [ 1.7768e+01],
#         [ 4.3007e+00],
#         [ 1.3561e+01],
#         [ 2.2036e+01],
#         [ 4.6856e+01],
#         [ 7.7122e-05],
#         [ 4.0206e+01],
#         [ 7.3109e-02],
#         [ 4.2405e+01],
#         [ 3.3022e+01],
#         [ 6.9507e-01],
#         [ 3.4226e+01],
#         [ 1.3421e+01],
#         [ 2.3472e+01],
#         [ 1.6251e-05],
#         [ 6.5708e+00],
#         [ 2.1347e+00],
#         [ 1.7303e-01],
#         [ 5.1154e-01],
#         [ 6.0922e+00],
#         [ 1.4708e+01],
#         [ 2.1073e+01],
#         [ 3.3681e+01],
#         [ 1.7580e+00],
#         [ 4.6328e+01],
#         [ 8.7856e+00],
#         [ 2.1263e+01],
#         [ 1.5606e-05],
#         [ 2.0166e-01],
#         [ 2.1512e+00],
#         [ 4.3429e-04],
#         [ 3.3147e+00],
#         [ 2.7331e+01],
#         [ 9.4446e-01],
#         [ 1.5938e+00],
#         [ 3.5172e+01],
#         [ 4.1986e+01],
#         [ 2.2096e+01],
#         [ 0.0000e+00],
#         [ 3.4161e-01],
#         [ 4.6611e+01],
#         [ 3.8201e+01],
#         [ 4.6872e+01],
#         [ 1.1079e+01],
#         [ 1.0527e+00],
#         [ 3.0204e-06],
#         [ 3.5664e+01],
#         [ 6.9053e+00],
#         [ 2.0267e+01],
#         [ 3.5379e+01],
#         [ 3.6439e+01],
#         [ 0.0000e+00],
#         [ 3.9690e+01],
#         [ 5.1341e+01],
#         [ 0.0000e+00],
#         [ 3.2024e+00],
#         [ 4.8424e+01],
#         [ 3.0179e+01],
#         [-1.3841e-06],
#         [ 2.8658e+01],
#         [ 2.0067e+01],
#         [ 0.0000e+00],
#         [ 2.7245e+01],
#         [ 2.4530e-01],
#         [ 1.3284e+01],
#         [ 2.8928e+01],
#         [ 1.1700e+00],
#         [ 4.3355e+00],
#         [-9.7463e-07],
#         [ 2.3143e+01],
#         [ 4.6498e+01],
#         [ 8.8147e+00],
#         [ 2.4162e+01],
#         [ 2.1188e+01],
#         [ 4.7860e+00],
#         [ 3.8794e+00],
#         [ 2.0222e-01],
#         [ 1.0712e+01],
#         [ 5.3214e+01],
#         [ 2.3469e+01],
#         [ 3.5745e+00],
#         [ 4.9030e+00],
#         [ 1.0778e+01],
#         [ 3.7895e+01],
#         [ 5.7857e-06],
#         [ 1.7030e-02],
#         [ 4.6471e+01],
#         [ 0.0000e+00],
#         [ 4.4354e-06],
#         [ 1.1529e-01],
#         [ 4.5462e+01],
#         [ 3.6899e+01],
#         [ 4.9687e+00],
#         [ 7.4698e+00],
#         [ 2.1457e+01]], grad_fn=<CopySlices>)

# %%
f_o = torch.zeros(size = (500,4))

# First order DY/DX

for i in range(X.shape[0]):
  f_o[i] = torch.autograd.functional.jacobian( euro_vanilla_call, X[i])

print(f_o.shape) # m samples by n features 
  
print(f_o)
# Out:
# torch.Size([500, 4])
# tensor([[ 0.6887, 10.8391, 38.5158, 33.2855],
#         [ 0.2022,  2.2232, 16.5465, 21.9077],
#         [ 0.3973,  3.7116, 39.1187, 39.6127],
#         ...,
#         [ 0.2916,  3.5021, 21.8851, 27.0980],
#         [ 0.5091,  5.9063, 30.0435, 32.9135],
#         [ 0.6454,  5.1792, 80.7346, 51.7910]])

# %%
# Data Collection

x = X.type(torch.FloatTensor)
y = y.type(torch.FloatTensor)
f_o = f_o.type(torch.FloatTensor)

print(X.shape)
print(y.shape)
print(f_o.shape)
# Out:
# torch.Size([500, 4])
# torch.Size([500, 1])
# torch.Size([500, 4])

# %%
# Pre-processing for pytorch. 

full_data = torch.utils.data.TensorDataset(X , y, f_o)
train, val = random_split(full_data, [400, 100])
train_loader = DataLoader(train, batch_size = 50, shuffle=False , num_workers =0) # hardcore
val_loader = DataLoader(val, batch_size = 50 , shuffle=False , num_workers =0)

#X_train = train
#X_val, y_val, f_o_val, s_o_val = val

# %%
# Paramters and hyperparamters 
input_size = 4 # x features
hidden_size_1 = 50
hidden_size_2 = 30
output_size = 1 # y output of training 

learning_rate = 0.001 # hyperparameter
num_epochs = 500 # hyperparameter    \ 250 ->  1 epoch
                                      # 250/32 = 6.2...    - > updating my weights every 6 training samples. 
#    SGD, ADAM, RMSPROP AND MORE .    Wi+1 = Wi - lr* gradient L / wrt to W   goes to minimum    -> update weights
#                                     Bi+1 = Bi - lr* gradient L / wrt to B  goes to minimum     -> Update biases 
alpha = 1 
beta = 0.5

# %%
class TwinFirstOrderNetwork(pl.LightningModule):
  
  def __init__(self):
    super(TwinFirstOrderNetwork,self).__init__()
    self.layer_1 = nn.Linear(input_size, hidden_size_1) # linear layer
    self.layer_2 = nn.Linear(hidden_size_1, hidden_size_2)
    self.layer_3 = nn.Linear(hidden_size_2, output_size)

    self.softplus = nn.Softplus() # activation functions
    self.loss = nn.MSELoss() # MSEloss()

    self.automatic_optimization = False # Turn off automatic optimization. Turns off backprop automatically on lighting so we can do backprop operations manually such as in pytorch

  def forward(self, x):
    # layer 1
    x = self.layer_1(x)
    x = self.softplus(x)

    # layer 2
    x = self.layer_2(x)
    x = self.softplus(x)

    # layer 3 
    x = self.layer_3(x)

    return x


  def training_step(self, train_batch, batch_idx):
    opt = self.optimizers()
    opt.zero_grad()

    x, y, f_o  = train_batch
    predicted_y = self.forward(x)
    # loop over batch
    predicted_f_o = torch.zeros(size=(x.shape[0], 4))
    for i in range(x.shape[0]): # x_shape is the batch size
      predicted_f_o[i] = torch.autograd.functional.jacobian(self.forward, x[i], create_graph=True, strict=True)

    loss = alpha * self.loss(y, predicted_y) + beta * self.loss( f_o, predicted_f_o) 

    loss.backward(retain_graph=True) # keeps gradeints the same and not zero when first backprop is done so we can backprop over again (two backprops to train to get second order derivatives) 

    opt.step() # Every batch. 

    self.log('train_loss', loss)
    print(loss)
    return loss
    


  def validation_step(self, val_batch, batch_idx):
    x, y, f_o = val_batch
    predicted_y = self.forward(x)
    # loop over batch
    predicted_f_o = torch.zeros(size=(x.shape[0], 4))
    for i in range(x.shape[0]): # x_shape is the batch size
      predicted_f_o[i] = torch.autograd.functional.jacobian(self.forward, x[i], create_graph=True, strict=True) # https://github.com/pytorch/pytorch/issues/46918 - Can show we need create_graph to be true as it backpropagets through the graph

    loss = alpha * self.loss(y, predicted_y) + beta * self.loss( f_o, predicted_f_o) 
    self.log('val_loss', loss)

    return loss


  def configure_optimizers(self):
    return torch.optim.Adam(self.parameters(), lr=1e-3)

# %%
trainer = pl.Trainer(max_epochs= 50)
# https://www.machinecurve.com/index.php/question/how-to-set-number-of-epochs-in-pytorch-lightning/
model = TwinFirstOrderNetwork() # Trained. 

trainer.fit(model, train_loader, val_loader)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
#
#   | Name     | Type     | Params
# --------------------------------------
# 0 | layer_1  | Linear   | 250
# 1 | layer_2  | Linear   | 1.5 K
# 2 | layer_3  | Linear   | 31
# 3 | softplus | Softplus | 0
# 4 | loss     | MSELoss  | 0
# --------------------------------------
# 1.8 K     Trainable params
# 0         Non-trainable params
# 1.8 K     Total params
# 0.007     Total estimated model params size (MB)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/data_loading.py:323: UserWarning: The number of training samples (8) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# tensor(1263.2111, grad_fn=<AddBackward0>)
# tensor(1733.2598, grad_fn=<AddBackward0>)
# tensor(1415.3085, grad_fn=<AddBackward0>)
# tensor(1440.3762, grad_fn=<AddBackward0>)
# tensor(1131.1421, grad_fn=<AddBackward0>)
# tensor(790.4475, grad_fn=<AddBackward0>)
# tensor(1097.4757, grad_fn=<AddBackward0>)
# tensor(1218.9763, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(992.8647, grad_fn=<AddBackward0>)
# tensor(1355.5260, grad_fn=<AddBackward0>)
# tensor(1098.5601, grad_fn=<AddBackward0>)
# tensor(1154.3967, grad_fn=<AddBackward0>)
# tensor(861.5032, grad_fn=<AddBackward0>)
# tensor(599.2560, grad_fn=<AddBackward0>)
# tensor(828.9618, grad_fn=<AddBackward0>)
# tensor(983.2551, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(812.6588, grad_fn=<AddBackward0>)
# tensor(1087.2828, grad_fn=<AddBackward0>)
# tensor(898.0640, grad_fn=<AddBackward0>)
# tensor(987.0087, grad_fn=<AddBackward0>)
# tensor(717.6543, grad_fn=<AddBackward0>)
# tensor(520.6681, grad_fn=<AddBackward0>)
# tensor(700.5815, grad_fn=<AddBackward0>)
# tensor(876.7405, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(750.8785, grad_fn=<AddBackward0>)
# tensor(958.2054, grad_fn=<AddBackward0>)
# tensor(825.4130, grad_fn=<AddBackward0>)
# tensor(939.1276, grad_fn=<AddBackward0>)
# tensor(691.2167, grad_fn=<AddBackward0>)
# tensor(535.8431, grad_fn=<AddBackward0>)
# tensor(689.2867, grad_fn=<AddBackward0>)
# tensor(871.9793, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(767.7870, grad_fn=<AddBackward0>)
# tensor(936.9055, grad_fn=<AddBackward0>)
# tensor(829.3542, grad_fn=<AddBackward0>)
# tensor(948.0607, grad_fn=<AddBackward0>)
# tensor(703.3200, grad_fn=<AddBackward0>)
# tensor(551.9664, grad_fn=<AddBackward0>)
# tensor(695.2787, grad_fn=<AddBackward0>)
# tensor(874.1374, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(766.9302, grad_fn=<AddBackward0>)
# tensor(936.8563, grad_fn=<AddBackward0>)
# tensor(824.9763, grad_fn=<AddBackward0>)
# tensor(941.0702, grad_fn=<AddBackward0>)
# tensor(692.7874, grad_fn=<AddBackward0>)
# tensor(532.8671, grad_fn=<AddBackward0>)
# tensor(684.4923, grad_fn=<AddBackward0>)
# tensor(865.1775, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(751.8769, grad_fn=<AddBackward0>)
# tensor(946.7684, grad_fn=<AddBackward0>)
# tensor(823.2526, grad_fn=<AddBackward0>)
# tensor(937.8577, grad_fn=<AddBackward0>)
# tensor(687.6150, grad_fn=<AddBackward0>)
# tensor(520.2711, grad_fn=<AddBackward0>)
# tensor(683.3159, grad_fn=<AddBackward0>)
# tensor(865.3745, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(748.6315, grad_fn=<AddBackward0>)
# tensor(951.8969, grad_fn=<AddBackward0>)
# tensor(823.7101, grad_fn=<AddBackward0>)
# tensor(937.4669, grad_fn=<AddBackward0>)
# tensor(686.8912, grad_fn=<AddBackward0>)
# tensor(519.2300, grad_fn=<AddBackward0>)
# tensor(682.4958, grad_fn=<AddBackward0>)
# tensor(864.1237, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(747.9690, grad_fn=<AddBackward0>)
# tensor(949.0044, grad_fn=<AddBackward0>)
# tensor(821.6086, grad_fn=<AddBackward0>)
# tensor(935.5761, grad_fn=<AddBackward0>)
# tensor(685.5940, grad_fn=<AddBackward0>)
# tensor(519.7097, grad_fn=<AddBackward0>)
# tensor(680.4961, grad_fn=<AddBackward0>)
# tensor(861.1582, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(746.5330, grad_fn=<AddBackward0>)
# tensor(944.0376, grad_fn=<AddBackward0>)
# tensor(818.2777, grad_fn=<AddBackward0>)
# tensor(932.7242, grad_fn=<AddBackward0>)
# tensor(683.4509, grad_fn=<AddBackward0>)
# tensor(518.0900, grad_fn=<AddBackward0>)
# tensor(678.5047, grad_fn=<AddBackward0>)
# tensor(858.8621, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(744.9641, grad_fn=<AddBackward0>)
# tensor(941.0009, grad_fn=<AddBackward0>)
# tensor(815.9233, grad_fn=<AddBackward0>)
# tensor(930.7220, grad_fn=<AddBackward0>)
# tensor(682.0848, grad_fn=<AddBackward0>)
# tensor(517.3987, grad_fn=<AddBackward0>)
# tensor(677.2487, grad_fn=<AddBackward0>)
# tensor(857.2859, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(743.8293, grad_fn=<AddBackward0>)
# tensor(938.8775, grad_fn=<AddBackward0>)
# tensor(814.3229, grad_fn=<AddBackward0>)
# tensor(929.3014, grad_fn=<AddBackward0>)
# tensor(681.0784, grad_fn=<AddBackward0>)
# tensor(516.8016, grad_fn=<AddBackward0>)
# tensor(676.2045, grad_fn=<AddBackward0>)
# tensor(855.8962, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(742.7594, grad_fn=<AddBackward0>)
# tensor(936.8332, grad_fn=<AddBackward0>)
# tensor(812.7805, grad_fn=<AddBackward0>)
# tensor(927.7798, grad_fn=<AddBackward0>)
# tensor(679.7495, grad_fn=<AddBackward0>)
# tensor(515.1644, grad_fn=<AddBackward0>)
# tensor(674.8905, grad_fn=<AddBackward0>)
# tensor(854.3227, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(741.1198, grad_fn=<AddBackward0>)
# tensor(935.6682, grad_fn=<AddBackward0>)
# tensor(811.2468, grad_fn=<AddBackward0>)
# tensor(926.1801, grad_fn=<AddBackward0>)
# tensor(678.3844, grad_fn=<AddBackward0>)
# tensor(513.7428, grad_fn=<AddBackward0>)
# tensor(673.6428, grad_fn=<AddBackward0>)
# tensor(852.7213, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(739.6898, grad_fn=<AddBackward0>)
# tensor(933.7355, grad_fn=<AddBackward0>)
# tensor(809.5027, grad_fn=<AddBackward0>)
# tensor(924.4680, grad_fn=<AddBackward0>)
# tensor(676.8771, grad_fn=<AddBackward0>)
# tensor(511.8433, grad_fn=<AddBackward0>)
# tensor(672.1435, grad_fn=<AddBackward0>)
# tensor(850.8111, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(737.6015, grad_fn=<AddBackward0>)
# tensor(932.3432, grad_fn=<AddBackward0>)
# tensor(807.4626, grad_fn=<AddBackward0>)
# tensor(922.2877, grad_fn=<AddBackward0>)
# tensor(674.8807, grad_fn=<AddBackward0>)
# tensor(509.4767, grad_fn=<AddBackward0>)
# tensor(670.1445, grad_fn=<AddBackward0>)
# tensor(848.0054, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(734.7476, grad_fn=<AddBackward0>)
# tensor(929.1102, grad_fn=<AddBackward0>)
# tensor(803.8256, grad_fn=<AddBackward0>)
# tensor(918.5266, grad_fn=<AddBackward0>)
# tensor(671.3911, grad_fn=<AddBackward0>)
# tensor(504.9016, grad_fn=<AddBackward0>)
# tensor(666.2986, grad_fn=<AddBackward0>)
# tensor(842.8746, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(728.9584, grad_fn=<AddBackward0>)
# tensor(925.3306, grad_fn=<AddBackward0>)
# tensor(797.8160, grad_fn=<AddBackward0>)
# tensor(912.4424, grad_fn=<AddBackward0>)
# tensor(666.0451, grad_fn=<AddBackward0>)
# tensor(498.5749, grad_fn=<AddBackward0>)
# tensor(661.1394, grad_fn=<AddBackward0>)
# tensor(836.5135, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(722.6432, grad_fn=<AddBackward0>)
# tensor(920.7626, grad_fn=<AddBackward0>)
# tensor(791.0073, grad_fn=<AddBackward0>)
# tensor(906.5658, grad_fn=<AddBackward0>)
# tensor(661.9783, grad_fn=<AddBackward0>)
# tensor(495.9282, grad_fn=<AddBackward0>)
# tensor(657.3507, grad_fn=<AddBackward0>)
# tensor(830.7686, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(717.9541, grad_fn=<AddBackward0>)
# tensor(913.3547, grad_fn=<AddBackward0>)
# tensor(784.2753, grad_fn=<AddBackward0>)
# tensor(900.1798, grad_fn=<AddBackward0>)
# tensor(656.3635, grad_fn=<AddBackward0>)
# tensor(488.8429, grad_fn=<AddBackward0>)
# tensor(651.5057, grad_fn=<AddBackward0>)
# tensor(823.8264, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(711.2018, grad_fn=<AddBackward0>)
# tensor(907.3250, grad_fn=<AddBackward0>)
# tensor(776.7209, grad_fn=<AddBackward0>)
# tensor(893.0005, grad_fn=<AddBackward0>)
# tensor(651.0466, grad_fn=<AddBackward0>)
# tensor(484.1827, grad_fn=<AddBackward0>)
# tensor(646.2570, grad_fn=<AddBackward0>)
# tensor(816.1353, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(704.6042, grad_fn=<AddBackward0>)
# tensor(899.9901, grad_fn=<AddBackward0>)
# tensor(768.6678, grad_fn=<AddBackward0>)
# tensor(885.3036, grad_fn=<AddBackward0>)
# tensor(644.2977, grad_fn=<AddBackward0>)
# tensor(476.5555, grad_fn=<AddBackward0>)
# tensor(639.6113, grad_fn=<AddBackward0>)
# tensor(807.7808, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(697.2364, grad_fn=<AddBackward0>)
# tensor(890.8389, grad_fn=<AddBackward0>)
# tensor(759.0962, grad_fn=<AddBackward0>)
# tensor(875.5483, grad_fn=<AddBackward0>)
# tensor(636.2677, grad_fn=<AddBackward0>)
# tensor(467.8387, grad_fn=<AddBackward0>)
# tensor(630.2443, grad_fn=<AddBackward0>)
# tensor(795.4940, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(685.5839, grad_fn=<AddBackward0>)
# tensor(878.7507, grad_fn=<AddBackward0>)
# tensor(744.7075, grad_fn=<AddBackward0>)
# tensor(859.2980, grad_fn=<AddBackward0>)
# tensor(621.5292, grad_fn=<AddBackward0>)
# tensor(452.5281, grad_fn=<AddBackward0>)
# tensor(614.4951, grad_fn=<AddBackward0>)
# tensor(776.9352, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(668.7899, grad_fn=<AddBackward0>)
# tensor(859.3079, grad_fn=<AddBackward0>)
# tensor(725.5660, grad_fn=<AddBackward0>)
# tensor(838.3055, grad_fn=<AddBackward0>)
# tensor(606.4171, grad_fn=<AddBackward0>)
# tensor(439.4236, grad_fn=<AddBackward0>)
# tensor(599.6043, grad_fn=<AddBackward0>)
# tensor(759.5490, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(654.0005, grad_fn=<AddBackward0>)
# tensor(843.8688, grad_fn=<AddBackward0>)
# tensor(708.8630, grad_fn=<AddBackward0>)
# tensor(820.9796, grad_fn=<AddBackward0>)
# tensor(595.2658, grad_fn=<AddBackward0>)
# tensor(430.8909, grad_fn=<AddBackward0>)
# tensor(589.5421, grad_fn=<AddBackward0>)
# tensor(745.3534, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(642.9811, grad_fn=<AddBackward0>)
# tensor(831.6016, grad_fn=<AddBackward0>)
# tensor(695.7655, grad_fn=<AddBackward0>)
# tensor(806.5070, grad_fn=<AddBackward0>)
# tensor(584.3302, grad_fn=<AddBackward0>)
# tensor(422.1677, grad_fn=<AddBackward0>)
# tensor(580.5525, grad_fn=<AddBackward0>)
# tensor(732.6315, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(632.6874, grad_fn=<AddBackward0>)
# tensor(816.5972, grad_fn=<AddBackward0>)
# tensor(683.9599, grad_fn=<AddBackward0>)
# tensor(793.4445, grad_fn=<AddBackward0>)
# tensor(572.4167, grad_fn=<AddBackward0>)
# tensor(410.8170, grad_fn=<AddBackward0>)
# tensor(569.1735, grad_fn=<AddBackward0>)
# tensor(719.8423, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(622.3030, grad_fn=<AddBackward0>)
# tensor(800.2606, grad_fn=<AddBackward0>)
# tensor(671.1597, grad_fn=<AddBackward0>)
# tensor(779.5135, grad_fn=<AddBackward0>)
# tensor(561.3875, grad_fn=<AddBackward0>)
# tensor(400.3323, grad_fn=<AddBackward0>)
# tensor(556.8935, grad_fn=<AddBackward0>)
# tensor(706.5965, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(611.8994, grad_fn=<AddBackward0>)
# tensor(786.8396, grad_fn=<AddBackward0>)
# tensor(658.5447, grad_fn=<AddBackward0>)
# tensor(764.9722, grad_fn=<AddBackward0>)
# tensor(551.0104, grad_fn=<AddBackward0>)
# tensor(391.8442, grad_fn=<AddBackward0>)
# tensor(545.6335, grad_fn=<AddBackward0>)
# tensor(693.0869, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(601.4087, grad_fn=<AddBackward0>)
# tensor(774.9649, grad_fn=<AddBackward0>)
# tensor(646.4433, grad_fn=<AddBackward0>)
# tensor(750.3538, grad_fn=<AddBackward0>)
# tensor(540.0829, grad_fn=<AddBackward0>)
# tensor(383.5385, grad_fn=<AddBackward0>)
# tensor(534.8740, grad_fn=<AddBackward0>)
# tensor(679.3171, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(590.5239, grad_fn=<AddBackward0>)
# tensor(761.8422, grad_fn=<AddBackward0>)
# tensor(634.3740, grad_fn=<AddBackward0>)
# tensor(735.5886, grad_fn=<AddBackward0>)
# tensor(528.1784, grad_fn=<AddBackward0>)
# tensor(374.1720, grad_fn=<AddBackward0>)
# tensor(523.4358, grad_fn=<AddBackward0>)
# tensor(665.3121, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(579.2561, grad_fn=<AddBackward0>)
# tensor(746.9244, grad_fn=<AddBackward0>)
# tensor(621.8612, grad_fn=<AddBackward0>)
# tensor(720.4063, grad_fn=<AddBackward0>)
# tensor(515.8534, grad_fn=<AddBackward0>)
# tensor(364.1507, grad_fn=<AddBackward0>)
# tensor(510.9940, grad_fn=<AddBackward0>)
# tensor(651.0184, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(567.8419, grad_fn=<AddBackward0>)
# tensor(731.3990, grad_fn=<AddBackward0>)
# tensor(608.9444, grad_fn=<AddBackward0>)
# tensor(704.6708, grad_fn=<AddBackward0>)
# tensor(503.5999, grad_fn=<AddBackward0>)
# tensor(354.3445, grad_fn=<AddBackward0>)
# tensor(498.0635, grad_fn=<AddBackward0>)
# tensor(636.4393, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(556.4034, grad_fn=<AddBackward0>)
# tensor(716.1469, grad_fn=<AddBackward0>)
# tensor(595.9255, grad_fn=<AddBackward0>)
# tensor(688.5052, grad_fn=<AddBackward0>)
# tensor(491.4495, grad_fn=<AddBackward0>)
# tensor(345.0490, grad_fn=<AddBackward0>)
# tensor(485.1105, grad_fn=<AddBackward0>)
# tensor(621.6464, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(544.9286, grad_fn=<AddBackward0>)
# tensor(701.1187, grad_fn=<AddBackward0>)
# tensor(582.9807, grad_fn=<AddBackward0>)
# tensor(672.0807, grad_fn=<AddBackward0>)
# tensor(479.2168, grad_fn=<AddBackward0>)
# tensor(336.0622, grad_fn=<AddBackward0>)
# tensor(472.2132, grad_fn=<AddBackward0>)
# tensor(606.7184, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(533.3651, grad_fn=<AddBackward0>)
# tensor(685.8875, grad_fn=<AddBackward0>)
# tensor(570.1258, grad_fn=<AddBackward0>)
# tensor(655.5050, grad_fn=<AddBackward0>)
# tensor(466.7808, grad_fn=<AddBackward0>)
# tensor(327.1244, grad_fn=<AddBackward0>)
# tensor(459.2503, grad_fn=<AddBackward0>)
# tensor(591.7415, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(521.7191, grad_fn=<AddBackward0>)
# tensor(670.1856, grad_fn=<AddBackward0>)
# tensor(557.3231, grad_fn=<AddBackward0>)
# tensor(638.8461, grad_fn=<AddBackward0>)
# tensor(454.1926, grad_fn=<AddBackward0>)
# tensor(318.1570, grad_fn=<AddBackward0>)
# tensor(446.1245, grad_fn=<AddBackward0>)
# tensor(576.8080, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(510.0828, grad_fn=<AddBackward0>)
# tensor(654.0465, grad_fn=<AddBackward0>)
# tensor(544.5658, grad_fn=<AddBackward0>)
# tensor(622.1692, grad_fn=<AddBackward0>)
# tensor(441.6201, grad_fn=<AddBackward0>)
# tensor(309.2595, grad_fn=<AddBackward0>)
# tensor(432.8556, grad_fn=<AddBackward0>)
# tensor(562.0120, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(498.5909, grad_fn=<AddBackward0>)
# tensor(637.6849, grad_fn=<AddBackward0>)
# tensor(531.9067, grad_fn=<AddBackward0>)
# tensor(605.5585, grad_fn=<AddBackward0>)
# tensor(429.2447, grad_fn=<AddBackward0>)
# tensor(300.5980, grad_fn=<AddBackward0>)
# tensor(419.5607, grad_fn=<AddBackward0>)
# tensor(547.4502, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(487.3693, grad_fn=<AddBackward0>)
# tensor(621.3319, grad_fn=<AddBackward0>)
# tensor(519.4415, grad_fn=<AddBackward0>)
# tensor(589.1208, grad_fn=<AddBackward0>)
# tensor(417.1994, grad_fn=<AddBackward0>)
# tensor(292.3103, grad_fn=<AddBackward0>)
# tensor(406.3907, grad_fn=<AddBackward0>)
# tensor(533.2208, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(476.5107, grad_fn=<AddBackward0>)
# tensor(605.1480, grad_fn=<AddBackward0>)
# tensor(507.2751, grad_fn=<AddBackward0>)
# tensor(572.9733, grad_fn=<AddBackward0>)
# tensor(405.5607, grad_fn=<AddBackward0>)
# tensor(284.4730, grad_fn=<AddBackward0>)
# tensor(393.4818, grad_fn=<AddBackward0>)
# tensor(519.4187, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(466.0757, grad_fn=<AddBackward0>)
# tensor(589.2177, grad_fn=<AddBackward0>)
# tensor(495.4994, grad_fn=<AddBackward0>)
# tensor(557.2294, grad_fn=<AddBackward0>)
# tensor(394.3684, grad_fn=<AddBackward0>)
# tensor(277.1143, grad_fn=<AddBackward0>)
# tensor(380.9396, grad_fn=<AddBackward0>)
# tensor(506.1312, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(456.1044, grad_fn=<AddBackward0>)
# tensor(573.5859, grad_fn=<AddBackward0>)
# tensor(484.1865, grad_fn=<AddBackward0>)
# tensor(541.9907, grad_fn=<AddBackward0>)
# tensor(383.6495, grad_fn=<AddBackward0>)
# tensor(270.2408, grad_fn=<AddBackward0>)
# tensor(368.8433, grad_fn=<AddBackward0>)
# tensor(493.4352, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(446.6277, grad_fn=<AddBackward0>)
# tensor(558.2902, grad_fn=<AddBackward0>)
# tensor(473.3889, grad_fn=<AddBackward0>)
# tensor(527.3418, grad_fn=<AddBackward0>)
# tensor(373.4314, grad_fn=<AddBackward0>)
# tensor(263.8558, grad_fn=<AddBackward0>)
# tensor(357.2552, grad_fn=<AddBackward0>)
# tensor(481.3925, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(437.6661, grad_fn=<AddBackward0>)
# tensor(543.3727, grad_fn=<AddBackward0>)
# tensor(463.1352, grad_fn=<AddBackward0>)
# tensor(513.3436, grad_fn=<AddBackward0>)
# tensor(363.7381, grad_fn=<AddBackward0>)
# tensor(257.9607, grad_fn=<AddBackward0>)
# tensor(346.2250, grad_fn=<AddBackward0>)
# tensor(470.0374, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(429.2076, grad_fn=<AddBackward0>)
# tensor(528.8675, grad_fn=<AddBackward0>)
# tensor(453.4065, grad_fn=<AddBackward0>)
# tensor(500.0217, grad_fn=<AddBackward0>)
# tensor(354.5801, grad_fn=<AddBackward0>)
# tensor(252.5578, grad_fn=<AddBackward0>)
# tensor(335.7954, grad_fn=<AddBackward0>)
# tensor(459.3881, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(421.2387, grad_fn=<AddBackward0>)
# tensor(514.8445, grad_fn=<AddBackward0>)
# tensor(444.1833, grad_fn=<AddBackward0>)
# tensor(487.4288, grad_fn=<AddBackward0>)
# tensor(346.0410, grad_fn=<AddBackward0>)
# tensor(247.6938, grad_fn=<AddBackward0>)
# tensor(325.9891, grad_fn=<AddBackward0>)
# tensor(449.5285, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(413.8785, grad_fn=<AddBackward0>)
# tensor(501.4480, grad_fn=<AddBackward0>)
# tensor(435.5492, grad_fn=<AddBackward0>)
# tensor(475.6513, grad_fn=<AddBackward0>)
# tensor(338.1980, grad_fn=<AddBackward0>)
# tensor(243.3816, grad_fn=<AddBackward0>)
# tensor(316.8593, grad_fn=<AddBackward0>)
# tensor(440.4058, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# tensor(406.9827, grad_fn=<AddBackward0>)
# tensor(488.5153, grad_fn=<AddBackward0>)
# tensor(427.1294, grad_fn=<AddBackward0>)
# tensor(465.4899, grad_fn=<AddBackward0>)
# tensor(330.8577, grad_fn=<AddBackward0>)
# tensor(238.8572, grad_fn=<AddBackward0>)
# tensor(307.9278, grad_fn=<AddBackward0>)
# tensor(432.1606, grad_fn=<AddBackward0>)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
